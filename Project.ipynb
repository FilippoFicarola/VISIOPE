# %% [markdown]
# **Training and validation summary (over all experiments)**:
#
# - **Model 1**: vgg19 pretrained + conv2D(32) + conv2D(32) + pooling + dropout(25) + conv2D(64) + conv2D(64) + pooling + dropout(0.25) + conv2D(64) + conv2D(64) + pooling + dropout(0.25) + flatten() + dense(512) + dropout(0.5) + dense(11):
#   - **Adam Optimizer**
#     - Epoch 1/30 -> loss: 2.2814 - accuracy: 0.1606 - val_loss: 2.1137 - val_accuracy: 0.2500
#     - Epoch 2/30 -> loss: 2.0742 - accuracy: 0.2371 - val_loss: 1.9780 - val_accuracy: 0.2827
#     - Epoch 3/30 -> loss: 2.0080 - accuracy: 0.2651 - val_loss: 1.9241 - val_accuracy: 0.2965
#     - ...
#     - Epoch 29/30 -> loss: 1.5315 - accuracy: 0.4545 - val_loss: 1.5475 - val_accuracy: 0.4528
#     - Epoch 30/30 -> loss: 1.5250 - accuracy: **0.4595** - val_loss: 1.5333 - val_accuracy: 0.4746
#
#   **Comments**:
#   1. Initial model.
#
# - **Model 2**:  vgg19 pretrained + flatten() + dense(512) + dropout(0.5) + dense(11), input_shape = (150, 150, 3):
#   - **Adam Optimizer**
#
#     - Epoch 1/30 -> loss: 2.0076 - accuracy: 0.3367 - val_loss: 1.5779 - val_accuracy: 0.4499
#     - Epoch 2/30 -> loss: 1.6577 - accuracy: 0.4203 - val_loss: 1.4434 - val_accuracy: 0.5160
#     - Epoch 3/30 -> loss: 1.5804 - accuracy: 0.4511 - val_loss: 1.4364 - val_accuracy: 0.5058
#     - ...
#     - Epoch 29/30 -> loss: 1.2489 - accuracy: 0.5619 - val_loss: 1.2222 - val_accuracy: 0.5836
#     - Epoch 30/30 -> loss: 1.2507 - accuracy: **0.5650** - val_loss: 1.2184 - val_accuracy: 0.5807
#
#   **Differences**:
#   1. Removed all additional layers proposed by the Initial model.
#
#   **Comments**:
#   1. Using only the pretrained model of vgg19 on ImageNet, we can see an higher accuracy w.r.t. the one got previously.
#
# - **Model 3**:  vgg19 pretrained + **conv2d(512) + conv2d(256) + conv2d(128) + pooling + dropout(0.25)** + flatten() + dense(512) + dropout(0.5) + dense(11), input_shape = (150, 150, 3):
#
#   - **Adam Optimizer**
#     - Epoch 1/30 -> loss: 2.0127 - accuracy: 0.2803 - val_loss: 1.6857 - val_accuracy: 0.4346
#     - Epoch 2/30 -> loss: 1.6627 - accuracy: 0.4192 - val_loss: 1.4965 - val_accuracy: 0.4884
#     - Epoch 3/30 -> loss: 1.5251 - accuracy: 0.4708 - val_loss: 1.3875 - val_accuracy: 0.5233
#     - ...
#     - Epoch 29/30 -> loss: 1.0184 - accuracy: 0.6651 - val_loss: 1.2938 - val_accuracy: 0.5923
#     - Epoch 30/30 -> loss: 0.9764 - **accuracy: 0.6707** - val_loss: 1.2831 - val_accuracy: 0.5843
#
#   **Differences**:
#   1. Added conv layer with 512 filters to the base model;
#   2. Added conv layer with 256 filters;
#   3. Added conv layer with 128 filters;
#   4. Added max pooling layer;
#   5. Added dropout layer;
#
#   **Comments**:
#   1. Accuracy improvement w.r.t. the previous experiment;
#   2. Accuracy results to be quite larger than val_accuracy, overfitting.
#
# - **Model 4**: vgg19 pretrained + **dropout(0.25)** + conv2d(512) + conv2d(256) + conv2d(128) + pooling + dropout(0.25) + flatten() + dense(512) + dropout(0.5) + dense(11), input_shape = (150, 150, 3):
#   - **Adam Optimizer**
#     - Epoch 1/30 -> loss: 2.0533 - accuracy: 0.2572 - val_loss: 1.7289 - val_accuracy: 0.4244
#     - Epoch 2/30 -> loss: 1.7106 - accuracy: 0.4089 - val_loss: 1.5919 - val_accuracy: 0.4455
#     - Epoch 3/30 -> loss: 1.5833 - accuracy: 0.4591 - val_loss: 1.4731 - val_accuracy: 0.4964
#     - ...
#     - Epoch 29/30 -> loss: 1.0828 - accuracy: 0.6399 - val_loss: 1.2577 - val_accuracy: 0.5923
#     - Epoch 30/30 -> loss: 1.0437 - **accuracy: 0.6481** - val_loss: 1.2134 - val_accuracy: 0.5930
#
#   **Differences**:
#   1. Added a dropout layer immediately after the base model.
#
#   **Comments**:
#   1. The addition of a dropout layer implied a little worsening about the training accuracy;
#   2. This choice was made to reduce overfitting.
#
# - **Model 5**: vgg19 pretrained + dropout(0.25) + conv2d(512) + conv2d(256) + pooling + dropout(0.25) + flatten() + dense(512) + dropout(0.5) + dense(11), input_shape = (224, 224, 3):
#   - **Adam Optimizer**
#     - Epoch 1/30 -> loss: 1.9483 - accuracy: 0.3098 - val_loss: 1.5837 - val_accuracy: 0.4528
#     - Epoch 2/30 -> loss: 1.6026 - accuracy: 0.4448 - val_loss: 1.3633 - val_accuracy: 0.5320
#     - Epoch 3/30 -> loss: 1.4645 - accuracy: 0.5060 - val_loss: 1.3839 - val_accuracy: 0.5138
#     - ...
#     - Epoch 29/30 -> loss: 0.9935 - accuracy: 0.6673 - val_loss: 1.1247 - val_accuracy: 0.6403
#     - Epoch 30/30 -> loss: 1.0069 - accuracy: **0.6687** - val_loss: 1.1569 - val_accuracy: 0.6163
#
#   - **SGD Optimizer**
#     - Epoch 1/30 -> loss: 2.2981 - accuracy: 0.1798 - val_loss: 2.0514 - val_accuracy: 0.2885
#     - Epoch 2/30 -> loss: 2.0101 - accuracy: 0.2751 - val_loss: 1.7983 - val_accuracy: 0.3459
#     - Epoch 3/30 -> loss: 1.8571 - accuracy: 0.3381 - val_loss: 1.6499 - val_accuracy: 0.4448
#     - ...
#     - Epoch 29/30 -> loss: 1.2354 - accuracy: 0.5727 - val_loss: 1.1793 - val_accuracy: 0.5894
#     - Epoch 30/30 -> loss: 1.2189 - accuracy: **0.5839** - val_loss: 1.1950 - val_accuracy: 0.5836
#
#   **Differences**:
#  1.   Increased the input_shape from (150, 150, 3) to (224, 224, 3).
#  2.   Removed the conv layer with 128 filters -> solved a dimension error previously bypassed by padding = 'same'.
#
#   **Comments**:
#   1. Increasing the input shape and removing a layer the error about dimensions is solved, previously bypassed by using "padding = 'same'". As a result, the accuracy increases.
#
# **Notes**:
#
# 1.  **accuracy** represents the highest value of accuracy reached during training;
# 2.  the pretrained model of vgg19 has been added without the dense layers (includeTop = false) and uses the ImageNet weights;

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Mar 13 14:32:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    51W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# import section
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Flatten, Dense, Dropout, Conv2D, Input, Activation
import matplotlib.pyplot as plt
import numpy as np
from keras import optimizers

# versions 
print("Tensorflow version %s" %tf.__version__)
print("Keras version %s" %keras.__version__)
# Out:
# Tensorflow version 2.11.0
# Keras version 2.11.0

# %%
# Dataset, Preprocessing & Data Augmentation
import os
from keras.applications.vgg19 import preprocess_input as vgg_preprocess
training = '/content/drive/MyDrive/VISIOPE/Dataset/train/'
testing = '/content/drive/MyDrive/VISIOPE/Dataset/test/'
validating = '/content/drive/MyDrive/VISIOPE/Dataset/valid/'

batch_size = 32
target_size = (224, 224) 

# Preprocessing & Data Augmentation 
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255, 
    shear_range = 0.2, 
    fill_mode = 'nearest', 
    zoom_range=0.2, 
    rotation_range=40, 
    width_shift_range=0.2, 
    height_shift_range=0.2, 
    horizontal_flip=True, 
    preprocessing_function=vgg_preprocess  #convert the input images from RGB to BGR, then will zero-center each color channel with respect to the ImageNet dataset
    )

# data generator for training data
train_generator = datagen.flow_from_directory(
    directory=training,
    target_size= target_size,
    color_mode="rgb",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    )

# data generator for testing data
test_generator = datagen.flow_from_directory(
    directory=testing,
    target_size=target_size,
    color_mode="rgb",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
)

# data generator for validating data
valid_generator = datagen.flow_from_directory(
    directory=validating,
    target_size=target_size,
    color_mode="rgb",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
)

num_samples = train_generator.n
num_classes = train_generator.num_classes
input_shape = train_generator.image_shape
classnames = [k for k, v in train_generator.class_indices.items()]

print()
print("Image input %s" %str(input_shape))
print()
print("Classes: %r" %classnames)
print()
print('Loaded %d training samples from %d classes.' %(num_samples,num_classes))
print('Loaded %d testing samples from %d classes.' %(test_generator.n,test_generator.num_classes))
print('Loaded %d validating samples from %d classes.' %(valid_generator.n,valid_generator.num_classes))
# Out:
# Found 6510 images belonging to 11 classes.
# Found 1411 images belonging to 11 classes.
# Found 1398 images belonging to 11 classes.
#
# Image input (224, 224, 3)
#
# Classes: ['creamy_paste', 'diced', 'floured', 'grated', 'juiced', 'jullienne', 'mixed', 'other', 'peeled', 'sliced', 'whole']
#
# Loaded 6510 training samples from 11 classes.
# Loaded 1411 testing samples from 11 classes.
# Loaded 1398 validating samples from 11 classes.

# %%
# Getting the VGG19 standard model pretrained on imagenet 
from tensorflow.keras.applications import vgg19

def get_vgg19_base_model(input_shape):

    # load VGG19 model without the final dense layers 
    vgg19_base_model = vgg19.VGG19(include_top= False, weights = 'imagenet', input_shape = input_shape)
    
    return vgg19_base_model

# %%
# modified model - this one corresponds to the best model achieved. In particular it is the 5-th experiment.
def VGG19_mod(input_shape, num_classes, optimizer, vgg19_frozen):
    
    # create modified model
    vgg19_modified = Sequential()

    # add the vgg19 base model with all layers frozen
    vgg19_modified.add(vgg19_frozen)

    # add additional layers to improve accuracy
    vgg19_modified.add(Dropout(0.25)) 
    vgg19_modified.add(Conv2D(filters=512, kernel_size=(3,3), activation="relu"))
    vgg19_modified.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    vgg19_modified.add(MaxPooling2D(pool_size = (2,2)))
    vgg19_modified.add(Dropout(0.25))

    # fully connected block
    vgg19_modified.add(Flatten()) 
    vgg19_modified.add(Dense(512, activation="relu"))
    vgg19_modified.add(Dropout(0.5))
    vgg19_modified.add(Dense(num_classes, activation='softmax')) #output layer
    
    # compile the model 
    vgg19_modified.compile(loss=keras.losses.categorical_crossentropy, optimizer=optimizer, metrics=['accuracy'])

    return vgg19_modified

# optimizers 
opt1 = keras.optimizers.Adam(learning_rate=0.001)
opt2 = keras.optimizers.SGD(learning_rate=0.01) 

# call the modified model...
vgg19_modified_1 = VGG19_mod(input_shape, num_classes, opt1, vgg19_frozen) #... with Adam optimizer
vgg19_modified_1.summary()

vgg19_modified_2 = VGG19_mod(input_shape, num_classes, opt2, vgg19_frozen) #... with SGD optimizer
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  dropout (Dropout)           (None, 7, 7, 512)         0
#
#  conv2d (Conv2D)             (None, 5, 5, 512)         2359808
#
#  conv2d_1 (Conv2D)           (None, 3, 3, 256)         1179904
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 256)        0
#  )
#
#  dropout_1 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 23,701,323
# Trainable params: 3,676,939
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Training and Validation (adam optimizer)
steps_per_epoch=train_generator.samples//train_generator.batch_size
val_steps=valid_generator.samples//valid_generator.batch_size
epochs = 30

try: 
    history1 = vgg19_modified_1.fit(train_generator, 
                  epochs=epochs, 
                  verbose = 1, 
                  steps_per_epoch = steps_per_epoch,
                  validation_data = valid_generator,
                  validation_steps = val_steps,
                 )
except KeyboardInterrupt:
    pass
# Out:
# Epoch 1/30
# 203/203 [==============================] - 1631s 8s/step - loss: 1.9518 - accuracy: 0.3090 - val_loss: 1.6815 - val_accuracy: 0.3939
# Epoch 2/30
# 203/203 [==============================] - 135s 667ms/step - loss: 1.5715 - accuracy: 0.4545 - val_loss: 1.4228 - val_accuracy: 0.5189
# Epoch 3/30
# 203/203 [==============================] - 135s 665ms/step - loss: 1.4335 - accuracy: 0.5151 - val_loss: 1.3473 - val_accuracy: 0.5422
# Epoch 4/30
# 203/203 [==============================] - 135s 668ms/step - loss: 1.3758 - accuracy: 0.5397 - val_loss: 1.3389 - val_accuracy: 0.5349
# Epoch 5/30
# 203/203 [==============================] - 136s 669ms/step - loss: 1.3463 - accuracy: 0.5465 - val_loss: 1.2480 - val_accuracy: 0.5625
# Epoch 6/30
# 203/203 [==============================] - 136s 672ms/step - loss: 1.3047 - accuracy: 0.5611 - val_loss: 1.3244 - val_accuracy: 0.5465
# Epoch 7/30
# 203/203 [==============================] - 136s 669ms/step - loss: 1.2634 - accuracy: 0.5730 - val_loss: 1.2627 - val_accuracy: 0.5574
# Epoch 8/30
# 203/203 [==============================] - 135s 664ms/step - loss: 1.2326 - accuracy: 0.5821 - val_loss: 1.2392 - val_accuracy: 0.5785
# Epoch 9/30
# 203/203 [==============================] - 135s 666ms/step - loss: 1.2179 - accuracy: 0.5931 - val_loss: 1.1817 - val_accuracy: 0.5916
# Epoch 10/30
# 203/203 [==============================] - 135s 668ms/step - loss: 1.1974 - accuracy: 0.5962 - val_loss: 1.1995 - val_accuracy: 0.5923
# Epoch 11/30
# 203/203 [==============================] - 136s 668ms/step - loss: 1.1923 - accuracy: 0.6010 - val_loss: 1.2323 - val_accuracy: 0.5938
# Epoch 12/30
# 203/203 [==============================] - 135s 666ms/step - loss: 1.1529 - accuracy: 0.6135 - val_loss: 1.2083 - val_accuracy: 0.5858
# Epoch 13/30
# 203/203 [==============================] - 137s 673ms/step - loss: 1.1430 - accuracy: 0.6161 - val_loss: 1.1306 - val_accuracy: 0.6061
# Epoch 14/30
# 203/203 [==============================] - 135s 668ms/step - loss: 1.1329 - accuracy: 0.6233 - val_loss: 1.2086 - val_accuracy: 0.5923
# Epoch 15/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.1285 - accuracy: 0.6199 - val_loss: 1.1686 - val_accuracy: 0.6163
# Epoch 16/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.1081 - accuracy: 0.6196 - val_loss: 1.1427 - val_accuracy: 0.6054
# Epoch 17/30
# 203/203 [==============================] - 136s 672ms/step - loss: 1.1167 - accuracy: 0.6280 - val_loss: 1.1514 - val_accuracy: 0.6068
# Epoch 18/30
# 203/203 [==============================] - 137s 676ms/step - loss: 1.0878 - accuracy: 0.6345 - val_loss: 1.1613 - val_accuracy: 0.6148
# Epoch 19/30
# 203/203 [==============================] - 137s 674ms/step - loss: 1.0703 - accuracy: 0.6343 - val_loss: 1.2084 - val_accuracy: 0.5967
# Epoch 20/30
# 203/203 [==============================] - 137s 673ms/step - loss: 1.0840 - accuracy: 0.6295 - val_loss: 1.1899 - val_accuracy: 0.6017
# Epoch 21/30
# 203/203 [==============================] - 137s 677ms/step - loss: 1.0671 - accuracy: 0.6426 - val_loss: 1.1865 - val_accuracy: 0.6054
# Epoch 22/30
# 203/203 [==============================] - 137s 677ms/step - loss: 1.0487 - accuracy: 0.6573 - val_loss: 1.2094 - val_accuracy: 0.6097
# Epoch 23/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.0642 - accuracy: 0.6412 - val_loss: 1.1487 - val_accuracy: 0.6119
# Epoch 24/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.0493 - accuracy: 0.6487 - val_loss: 1.1382 - val_accuracy: 0.6003
# Epoch 25/30
# 203/203 [==============================] - 137s 676ms/step - loss: 1.0383 - accuracy: 0.6477 - val_loss: 1.1756 - val_accuracy: 0.6090
# Epoch 26/30
# 203/203 [==============================] - 139s 687ms/step - loss: 1.0375 - accuracy: 0.6443 - val_loss: 1.1334 - val_accuracy: 0.6206
# Epoch 27/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.0281 - accuracy: 0.6536 - val_loss: 1.1260 - val_accuracy: 0.6301
# Epoch 28/30
# 203/203 [==============================] - 135s 667ms/step - loss: 1.0030 - accuracy: 0.6616 - val_loss: 1.1415 - val_accuracy: 0.6112
# Epoch 29/30
# 203/203 [==============================] - 136s 668ms/step - loss: 0.9979 - accuracy: 0.6653 - val_loss: 1.1059 - val_accuracy: 0.6330
# Epoch 30/30
# 203/203 [==============================] - 135s 663ms/step - loss: 1.0050 - accuracy: 0.6579 - val_loss: 1.1506 - val_accuracy: 0.6192

# %%
# Training and Validation (sgd optimizer) 
steps_per_epoch=train_generator.samples//train_generator.batch_size
val_steps=valid_generator.samples//valid_generator.batch_size
epochs = 30
try: 
   history2 = vgg19_modified_2.fit(train_generator, 
                 epochs=epochs, 
                 verbose = 1, 
                 steps_per_epoch = steps_per_epoch,
                 validation_data = valid_generator,
                 validation_steps = val_steps,
                )
except KeyboardInterrupt:
   pass
# Out:
# Epoch 1/30
# 203/203 [==============================] - 138s 672ms/step - loss: 2.2741 - accuracy: 0.1795 - val_loss: 2.0053 - val_accuracy: 0.2951
# Epoch 2/30
# 203/203 [==============================] - 135s 666ms/step - loss: 1.9830 - accuracy: 0.2864 - val_loss: 1.9384 - val_accuracy: 0.2812
# Epoch 3/30
# 203/203 [==============================] - 137s 673ms/step - loss: 1.8358 - accuracy: 0.3481 - val_loss: 1.6966 - val_accuracy: 0.4012
# Epoch 4/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.7436 - accuracy: 0.3827 - val_loss: 1.5625 - val_accuracy: 0.4629
# Epoch 5/30
# 203/203 [==============================] - 136s 669ms/step - loss: 1.6709 - accuracy: 0.4146 - val_loss: 1.5612 - val_accuracy: 0.4397
# Epoch 6/30
# 203/203 [==============================] - 136s 668ms/step - loss: 1.6405 - accuracy: 0.4288 - val_loss: 1.5514 - val_accuracy: 0.4688
# Epoch 7/30
# 203/203 [==============================] - 137s 673ms/step - loss: 1.5771 - accuracy: 0.4565 - val_loss: 1.4590 - val_accuracy: 0.4840
# Epoch 8/30
# 203/203 [==============================] - 138s 681ms/step - loss: 1.5432 - accuracy: 0.4680 - val_loss: 1.4182 - val_accuracy: 0.4956
# Epoch 9/30
# 203/203 [==============================] - 137s 676ms/step - loss: 1.5251 - accuracy: 0.4622 - val_loss: 1.3420 - val_accuracy: 0.5334
# Epoch 10/30
# 203/203 [==============================] - 135s 667ms/step - loss: 1.4782 - accuracy: 0.4833 - val_loss: 1.3936 - val_accuracy: 0.5196
# Epoch 11/30
# 203/203 [==============================] - 135s 666ms/step - loss: 1.4572 - accuracy: 0.4844 - val_loss: 1.3288 - val_accuracy: 0.5407
# Epoch 12/30
# 203/203 [==============================] - 135s 668ms/step - loss: 1.4494 - accuracy: 0.4951 - val_loss: 1.3848 - val_accuracy: 0.5094
# Epoch 13/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.4208 - accuracy: 0.5082 - val_loss: 1.3408 - val_accuracy: 0.5240
# Epoch 14/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.3849 - accuracy: 0.5205 - val_loss: 1.2892 - val_accuracy: 0.5494
# Epoch 15/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.3918 - accuracy: 0.5120 - val_loss: 1.2804 - val_accuracy: 0.5501
# Epoch 16/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.3687 - accuracy: 0.5273 - val_loss: 1.4672 - val_accuracy: 0.5000
# Epoch 17/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.3514 - accuracy: 0.5358 - val_loss: 1.2778 - val_accuracy: 0.5538
# Epoch 18/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.3429 - accuracy: 0.5369 - val_loss: 1.2987 - val_accuracy: 0.5422
# Epoch 19/30
# 203/203 [==============================] - 135s 667ms/step - loss: 1.3366 - accuracy: 0.5395 - val_loss: 1.1940 - val_accuracy: 0.5770
# Epoch 20/30
# 203/203 [==============================] - 136s 668ms/step - loss: 1.3007 - accuracy: 0.5587 - val_loss: 1.3342 - val_accuracy: 0.5429
# Epoch 21/30
# 203/203 [==============================] - 136s 672ms/step - loss: 1.2995 - accuracy: 0.5465 - val_loss: 1.2955 - val_accuracy: 0.5436
# Epoch 22/30
# 203/203 [==============================] - 136s 672ms/step - loss: 1.2875 - accuracy: 0.5556 - val_loss: 1.2412 - val_accuracy: 0.5756
# Epoch 23/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.2789 - accuracy: 0.5571 - val_loss: 1.2063 - val_accuracy: 0.5749
# Epoch 24/30
# 203/203 [==============================] - 135s 667ms/step - loss: 1.2667 - accuracy: 0.5621 - val_loss: 1.1621 - val_accuracy: 0.5988
# Epoch 25/30
# 203/203 [==============================] - 135s 666ms/step - loss: 1.2461 - accuracy: 0.5644 - val_loss: 1.1986 - val_accuracy: 0.5778
# Epoch 26/30
# 203/203 [==============================] - 135s 664ms/step - loss: 1.2551 - accuracy: 0.5722 - val_loss: 1.2071 - val_accuracy: 0.5814
# Epoch 27/30
# 203/203 [==============================] - 136s 670ms/step - loss: 1.2386 - accuracy: 0.5682 - val_loss: 1.2305 - val_accuracy: 0.5669
# Epoch 28/30
# 203/203 [==============================] - 136s 668ms/step - loss: 1.2272 - accuracy: 0.5776 - val_loss: 1.2060 - val_accuracy: 0.5719
# Epoch 29/30
# 203/203 [==============================] - 135s 667ms/step - loss: 1.2245 - accuracy: 0.5744 - val_loss: 1.2304 - val_accuracy: 0.5654
# Epoch 30/30
# 203/203 [==============================] - 136s 671ms/step - loss: 1.2098 - accuracy: 0.5750 - val_loss: 1.1949 - val_accuracy: 0.5988

# %%
# Check performance in terms of loss function and accuracy 

import matplotlib.pyplot as plt

# vgg19_modified_1 - summarize history for accuracy 
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('vgg19_modified(adam): accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0.0,1.0)
plt.xlim(0.0,30.0)
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# vgg19_modified_1 - summarize history for loss
plt.plot((history1.history['loss']))
plt.plot((history1.history['val_loss']))
plt.title('vgg19_modified(adam): loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim(0.7,2.3)
plt.xlim(0.0,30.0)
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# vgg19_modified_2 - summarize history for accuracy 
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('vgg19_modified(sgd): accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0.0,1.0)
plt.xlim(0.0,30.0)
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# vgg19_modified_2 - summarize history for loss
plt.plot((history2.history['loss']))
plt.plot((history2.history['val_loss']))
plt.title('vgg19_modified(sgd): loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim(0.7,2.3)
plt.xlim(0.0,30.0)
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Evaluation
score_1 = vgg19_modified_1.evaluate(x = test_generator, verbose = 1) 
score_2 = vgg19_modified_2.evaluate(x = test_generator, verbose = 1)

print()
print('Model compiled with Adam - Test loss:', score_1[0]) 
print('Model compiled with Adam - Test accuracy:', score_1[1])
#print()
print('Model compiled with SGD - Test loss:', score_2[0]) 
print('Model compiled with SGD - Test accuracy:', score_2[1])
# Out:
# 45/45 [==============================] - 342s 8s/step - loss: 1.1390 - accuracy: 0.6286
# 45/45 [==============================] - 25s 546ms/step - loss: 1.1870 - accuracy: 0.5974
#
# Model compiled with Adam - Test loss: 1.1389927864074707
# Model compiled with Adam - Test accuracy: 0.6286321878433228
# Model compiled with SGD - Test loss: 1.1869802474975586
# Model compiled with SGD - Test accuracy: 0.5974486470222473

# %%
# Freeze the vgg19 base model

# function to freeze layers
def freeze_layers(start_freeze, end_freeze):
  vgg19_frozen = get_vgg19_base_model(input_shape)
  count = 0
  for layer in vgg19_frozen.layers[:]:
    count += 1
    if (count >= start_freeze and count <= end_freeze):
      layer.trainable = False
  return vgg19_frozen

# Freeze layers from start_freeze to end_freeze (first layer: 1, last layer: 22)
start_freeze = 1 
end_freeze = 22
# note: we are freezing the whole model. In this way we are using the pretrained version of vgg19 on ImageNet, without changing the weights during training. 

# call freezing function
vgg19_frozen = freeze_layers(start_freeze = start_freeze, end_freeze = end_freeze)

# check that layers are actually frozen
check = 0
count = 0
print()
for layer in vgg19_frozen.layers[:]:
  count += 1
  print(count, layer, layer.trainable)
  if (count >= start_freeze and count <= end_freeze):
    if layer.trainable == False:
      check = 1
    else:
      check = 0
print()
print()
if check == 1:
  print('Layers from %d to %d have been correctly frozen' %(start_freeze,end_freeze))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
#
# 1 <keras.engine.input_layer.InputLayer object at 0x7f94bcf7f790> False
# 2 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bcf7fe50> False
# 3 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bcf8c100> False
# 4 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f94bcf8c340> False
# 5 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bcf91ee0> False
# 6 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc84e2e0> False
# 7 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f94bc855670> False
# 8 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc855a30> False
# 9 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc85b3d0> False
# 10 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc85e040> False
# 11 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc85e430> False
# 12 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f94bc869220> False
# 13 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc869e80> False
# 14 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc869580> False
# 15 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc864040> False
# 16 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc7f96a0> False
# 17 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f94bc7f9220> False
# 18 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc864a90> False
# 19 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc808190> False
# 20 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc808910> False
# 21 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f94bc803790> False
# 22 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f94bc817df0> False
#
#
# Layers from 1 to 22 have been correctly frozen

# %%
# Prediction

predictions_1 = vgg19_modified_1.predict(test_generator, verbose=1, steps=test_generator.n//test_generator.batch_size+1) #model compiled with adam
predictions_2 = vgg19_modified_2.predict(test_generator, verbose=1, steps=test_generator.n//test_generator.batch_size+1) #model compiled with sgd
# Out:
# 45/45 [==============================] - 25s 539ms/step
# 45/45 [==============================] - 25s 540ms/step

# %%
# Test results

import sklearn.metrics 
from sklearn.metrics import classification_report, confusion_matrix

# All classes
classes = ['creamy_paste', 'diced', 'floured', 'grated', 'juiced', 'jullienne', 'mixed', 'other', 'peeled', 'sliced', 'whole']

# True labels for test images
y_test = test_generator.classes[test_generator.index_array] 

# Predicted labels on test images
y_pred_1 = np.argmax(predictions_1, axis=-1) 
y_pred_2 = np.argmax(predictions_2, axis=-1)

# Classification report
print('Model compiled with Adam - Classification Report')
print(classification_report(y_true=y_test, y_pred=y_pred_1, labels=None, target_names=classes, digits=3))
print()
print('Model compiled with SGD - Classification Report')
print(classification_report(y_test, y_pred_2, labels=None, target_names=classes, digits=3))

# Confusion matrices
conf_matrix_1 = confusion_matrix(y_test, y_pred_1)
conf_matrix_2 = confusion_matrix(y_test, y_pred_2)

# Plot confusion matrix 1
fig1, axes1 = plt.subplots()
im1 = axes1.imshow(conf_matrix_1, interpolation='nearest', cmap=plt.cm.Blues)
axes1.figure.colorbar(im1, ax=axes1)
axes1.figure.set_size_inches(8,8)

# Show all ticks and labels
axes1.set(xticks=np.arange(conf_matrix_1.shape[1]),
        yticks=np.arange(conf_matrix_1.shape[0]),
        xticklabels=classes, yticklabels=classes,
        title='Confusion matrix (model with adam optimizer)',
        ylabel='True label',
        xlabel='Predicted label')

axes1.set_ylim(bottom=len(classes)-0.5, top=-0.5)
plt.setp(axes1.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

# Fill confusion matrix
fmt = 'd' 
th = conf_matrix_1.max() / 2. #threshold used to assign colors to the text inside the conf matrix in order to display it better.

for i in range(conf_matrix_1.shape[0]):
    for j in range(conf_matrix_1.shape[1]):
        axes1.text(j, i, format(conf_matrix_1[i, j], fmt),
                ha="center", va="center",
                color="white" if conf_matrix_1[i, j] > th else "black")
fig1.tight_layout()

# Plot confusion matrix 2

fig2, axes2 = plt.subplots()
im2 = axes2.imshow(conf_matrix_2, interpolation='nearest', cmap=plt.cm.Blues)
axes2.figure.colorbar(im2, ax=axes2)
axes2.figure.set_size_inches(8,8)

# Show all ticks and labels
axes2.set(xticks=np.arange(conf_matrix_2.shape[1]),
       yticks=np.arange(conf_matrix_2.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title='Confusion matrix (model with sgd optimizer)',
       ylabel='True label',
       xlabel='Predicted label')

axes2.set_ylim(bottom=len(classes)-0.5, top=-0.5)
plt.setp(axes2.get_xticklabels(), rotation=45, ha="right",
            rotation_mode="anchor")

# Fill confusion matrix
fmt = 'd' 
th = conf_matrix_2.max() / 2. #threshold used to assign colors to the text inside the conf matrix in order to display it better.

for i in range(conf_matrix_2.shape[0]):
   for j in range(conf_matrix_2.shape[1]):
       axes2.text(j, i, format(conf_matrix_2[i, j], fmt),
               ha="center", va="center",
               color="white" if conf_matrix_2[i, j] > th else "black")
fig2.tight_layout()
# Out:
# Model compiled with Adam - Classification Report
#               precision    recall  f1-score   support
#
# creamy_paste      0.584     0.628     0.605        94
#        diced      0.772     0.667     0.716       117
#      floured      0.748     0.669     0.706       124
#       grated      0.667     0.717     0.691       120
#       juiced      0.836     0.692     0.757       133
#    jullienne      0.748     0.656     0.699       131
#        mixed      0.909     0.857     0.882       105
#        other      0.447     0.328     0.378       128
#       peeled      0.488     0.670     0.565        88
#       sliced      0.490     0.612     0.544       196
#        whole      0.530     0.560     0.544       175
#
#     accuracy                          0.633      1411
#    macro avg      0.656     0.642     0.644      1411
# weighted avg      0.646     0.633     0.635      1411
#
#
# Model compiled with SGD - Classification Report
#               precision    recall  f1-score   support
#
# creamy_paste      0.639     0.489     0.554        94
#        diced      0.752     0.726     0.739       117
#      floured      0.605     0.718     0.657       124
#       grated      0.572     0.758     0.652       120
#       juiced      0.643     0.827     0.724       133
#    jullienne      0.654     0.679     0.667       131
#        mixed      0.863     0.781     0.820       105
#        other      0.427     0.250     0.315       128
#       peeled      0.490     0.545     0.516        88
#       sliced      0.541     0.408     0.465       196
#        whole      0.508     0.571     0.538       175
#
#     accuracy                          0.604      1411
#    macro avg      0.609     0.614     0.604      1411
# weighted avg      0.600     0.604     0.595      1411
